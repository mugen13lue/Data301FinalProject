# %%
user = "KELLIE"

if user == "KELLIE":
    dir_main = "/Users/Kellie/Documents/data301/proj/"
elif user == "MUGEN":
    dir_main = ""
else:
    raise Error
    
data_dir = dir_main + "datasets/"

# %%
# !ls $data_dir
# Out:
# Kickstarter_2016-04-15T02_09_04_328Z Kickstarter_2017-08-15T22_20_51_958Z
# Kickstarter_2016-06-15T02_04_49_697Z Kickstarter_2018-10-18
# Kickstarter_2016-08-15T02_04_03_829Z Kickstarter_2018-11-15
# Kickstarter_2016-10-15T02_04_11_689Z Kickstarter_2018-12-13
# Kickstarter_2016-12-15T22_20_52_411Z Kickstarter_2019-01-17
# Kickstarter_2017-06-15T22_20_03_059Z Kickstarter_2019-02-14

# %% [markdown]
# # Cleaning

# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize

pd.options.display.max_rows = 10

# %%
month_df = pd.DataFrame()
folder_name = "Kickstarter_2019-01-17/"
dir_contents = os.listdir(data_dir + folder_name)

for ks in dir_contents:
    baby_df = (pd.read_csv(data_dir +
                           folder_name +
                           ks)[["backers_count", "blurb", "category", "country", "created_at",
                                "currency", "deadline", "goal", "id", "launched_at", "name",
                                "pledged", "slug", "spotlight", "staff_pick", "state",
                                "state_changed_at", "urls", "usd_pledged"]])
    month_df = pd.concat([month_df, baby_df], ignore_index=True)

month_df.head()
# Out:
#    backers_count                                              blurb  \
# 0              1  An eco-friendly coffee table that is both func...
# 1              3  We take digital uploads and make them handpain...
# 2            243  We are a team of restaurant pros looking to fu...
# 3             27  Loosely-based on a Lakota legend, Grandfather ...
# 4              3  Save me is a feature film about a depression s...
#
#                                             category country  created_at  \
# 0  {"id":356,"name":"Woodworking","slug":"crafts/...      US  1473631551
# 1  {"id":23,"name":"Painting","slug":"art/paintin...      CA  1436540372
# 2  {"id":311,"name":"Food Trucks","slug":"food/fo...      US  1427218874
# 3  {"id":46,"name":"Children's Books","slug":"pub...      US  1495110632
# 4  {"id":298,"name":"Movie Theaters","slug":"film...      IE  1450121921
#
#   currency    deadline     goal          id  launched_at  \
# 0      USD  1480966943   5000.0  1504859185   1478371343
# 1      CAD  1440417634   1000.0    49266114   1437480034
# 2      USD  1431706954  35000.0  1228074690   1429114954
# 3      USD  1500217383   3000.0   330962986   1496329383
# 4      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name  pledged  \
# 0                            Industrial Bamboo Table    240.0
# 1  Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
# 3             Grandfather Thunder & The Night Horses   3115.0
# 4  Save Me-A film to hightlight depression (Cance...    601.0
#
#                                                 slug  spotlight  staff_pick  \
# 0                            industrial-bamboo-table      False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...      False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...       True        True
# 3           grandfather-thunder-and-the-night-horses       True       False
# 4                                          save-me-1      False       False
#
#         state  state_changed_at  \
# 0      failed        1480966943
# 1      failed        1440417634
# 2  successful        1431706954
# 3  successful        1500217384
# 4    canceled        1455065666
#
#                                                 urls   usd_pledged
# 0  {"web":{"project":"https://www.kickstarter.com...    240.000000
# 1  {"web":{"project":"https://www.kickstarter.com...    247.950175
# 2  {"web":{"project":"https://www.kickstarter.com...  41738.000000
# 3  {"web":{"project":"https://www.kickstarter.com...   3115.000000
# 4  {"web":{"project":"https://www.kickstarter.com...    660.680598

# %%
month_df.shape
# Out:
# (207848, 19)

# %% [markdown]
# ## Clean JSON Variables

# %%
import ast

json_cols = ["category", "urls"]
#json_cols = ["category", "creator", "photo", "urls", "location"]
# TODO: weren't able to successfully convert creator and location to JSON.
# ignoring these cols and moving on for now, but should revisit later

for col in json_cols:
  print(col)
  month_df[col] = month_df[col].fillna('')
  month_df[col] = month_df[col].apply(ast.literal_eval)
  
month_df.head(3)
# Out:
# category
# urls
#    backers_count                                              blurb  \
# 0              1  An eco-friendly coffee table that is both func...
# 1              3  We take digital uploads and make them handpain...
# 2            243  We are a team of restaurant pros looking to fu...
#
#                                             category country  created_at  \
# 0  {'id': 356, 'name': 'Woodworking', 'slug': 'cr...      US  1473631551
# 1  {'id': 23, 'name': 'Painting', 'slug': 'art/pa...      CA  1436540372
# 2  {'id': 311, 'name': 'Food Trucks', 'slug': 'fo...      US  1427218874
#
#   currency    deadline     goal          id  launched_at  \
# 0      USD  1480966943   5000.0  1504859185   1478371343
# 1      CAD  1440417634   1000.0    49266114   1437480034
# 2      USD  1431706954  35000.0  1228074690   1429114954
#
#                                                 name  pledged  \
# 0                            Industrial Bamboo Table    240.0
# 1  Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
#
#                                                 slug  spotlight  staff_pick  \
# 0                            industrial-bamboo-table      False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...      False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...       True        True
#
#         state  state_changed_at  \
# 0      failed        1480966943
# 1      failed        1440417634
# 2  successful        1431706954
#
#                                                 urls   usd_pledged
# 0  {'web': {'project': 'https://www.kickstarter.c...    240.000000
# 1  {'web': {'project': 'https://www.kickstarter.c...    247.950175
# 2  {'web': {'project': 'https://www.kickstarter.c...  41738.000000

# %%
category_exp = json_normalize(month_df["category"])
month_df = month_df.drop("category", axis=1)
month_df.head()
# Out:
#    backers_count                                              blurb country  \
# 0              1  An eco-friendly coffee table that is both func...      US
# 1              3  We take digital uploads and make them handpain...      CA
# 2            243  We are a team of restaurant pros looking to fu...      US
# 3             27  Loosely-based on a Lakota legend, Grandfather ...      US
# 4              3  Save me is a feature film about a depression s...      IE
#
#    created_at currency    deadline     goal          id  launched_at  \
# 0  1473631551      USD  1480966943   5000.0  1504859185   1478371343
# 1  1436540372      CAD  1440417634   1000.0    49266114   1437480034
# 2  1427218874      USD  1431706954  35000.0  1228074690   1429114954
# 3  1495110632      USD  1500217383   3000.0   330962986   1496329383
# 4  1450121921      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name  pledged  \
# 0                            Industrial Bamboo Table    240.0
# 1  Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
# 3             Grandfather Thunder & The Night Horses   3115.0
# 4  Save Me-A film to hightlight depression (Cance...    601.0
#
#                                                 slug  spotlight  staff_pick  \
# 0                            industrial-bamboo-table      False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...      False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...       True        True
# 3           grandfather-thunder-and-the-night-horses       True       False
# 4                                          save-me-1      False       False
#
#         state  state_changed_at  \
# 0      failed        1480966943
# 1      failed        1440417634
# 2  successful        1431706954
# 3  successful        1500217384
# 4    canceled        1455065666
#
#                                                 urls   usd_pledged
# 0  {'web': {'project': 'https://www.kickstarter.c...    240.000000
# 1  {'web': {'project': 'https://www.kickstarter.c...    247.950175
# 2  {'web': {'project': 'https://www.kickstarter.c...  41738.000000
# 3  {'web': {'project': 'https://www.kickstarter.c...   3115.000000
# 4  {'web': {'project': 'https://www.kickstarter.c...    660.680598

# %%
category_tups = category_exp.slug.str.split("/").apply(pd.Series)
category_tups.columns = ["parent_category", "category"]
month_df = pd.concat([month_df, category_tups], axis=1)
month_df.head()
# Out:
#    backers_count                                              blurb country  \
# 0              1  An eco-friendly coffee table that is both func...      US
# 1              3  We take digital uploads and make them handpain...      CA
# 2            243  We are a team of restaurant pros looking to fu...      US
# 3             27  Loosely-based on a Lakota legend, Grandfather ...      US
# 4              3  Save me is a feature film about a depression s...      IE
#
#    created_at currency    deadline     goal          id  launched_at  \
# 0  1473631551      USD  1480966943   5000.0  1504859185   1478371343
# 1  1436540372      CAD  1440417634   1000.0    49266114   1437480034
# 2  1427218874      USD  1431706954  35000.0  1228074690   1429114954
# 3  1495110632      USD  1500217383   3000.0   330962986   1496329383
# 4  1450121921      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name  pledged  \
# 0                            Industrial Bamboo Table    240.0
# 1  Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
# 3             Grandfather Thunder & The Night Horses   3115.0
# 4  Save Me-A film to hightlight depression (Cance...    601.0
#
#                                                 slug  spotlight  staff_pick  \
# 0                            industrial-bamboo-table      False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...      False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...       True        True
# 3           grandfather-thunder-and-the-night-horses       True       False
# 4                                          save-me-1      False       False
#
#         state  state_changed_at  \
# 0      failed        1480966943
# 1      failed        1440417634
# 2  successful        1431706954
# 3  successful        1500217384
# 4    canceled        1455065666
#
#                                                 urls   usd_pledged  \
# 0  {'web': {'project': 'https://www.kickstarter.c...    240.000000
# 1  {'web': {'project': 'https://www.kickstarter.c...    247.950175
# 2  {'web': {'project': 'https://www.kickstarter.c...  41738.000000
# 3  {'web': {'project': 'https://www.kickstarter.c...   3115.000000
# 4  {'web': {'project': 'https://www.kickstarter.c...    660.680598
#
#   parent_category          category
# 0          crafts       woodworking
# 1             art          painting
# 2            food       food trucks
# 3      publishing  children's books
# 4    film & video    movie theaters

# %%
urls_exp = json_normalize(month_df["urls"])
urls_exp = urls_exp[["web.project", "web.rewards"]]
urls_exp.columns = ["project_url", "rewards_url"]
urls_exp.head()
# Out:
#                                          project_url  \
# 0  https://www.kickstarter.com/projects/983022919...
# 1  https://www.kickstarter.com/projects/101531536...
# 2  https://www.kickstarter.com/projects/372111659...
# 3  https://www.kickstarter.com/projects/133655246...
# 4  https://www.kickstarter.com/projects/203240363...
#
#                                          rewards_url
# 0  https://www.kickstarter.com/projects/983022919...
# 1  https://www.kickstarter.com/projects/101531536...
# 2  https://www.kickstarter.com/projects/372111659...
# 3  https://www.kickstarter.com/projects/133655246...
# 4  https://www.kickstarter.com/projects/203240363...

# %%
month_df = pd.concat([month_df, urls_exp], axis=1)
month_df = month_df.drop("urls", axis=1)
month_df.head()
# Out:
#    backers_count                                              blurb country  \
# 0              1  An eco-friendly coffee table that is both func...      US
# 1              3  We take digital uploads and make them handpain...      CA
# 2            243  We are a team of restaurant pros looking to fu...      US
# 3             27  Loosely-based on a Lakota legend, Grandfather ...      US
# 4              3  Save me is a feature film about a depression s...      IE
#
#    created_at currency    deadline     goal          id  launched_at  \
# 0  1473631551      USD  1480966943   5000.0  1504859185   1478371343
# 1  1436540372      CAD  1440417634   1000.0    49266114   1437480034
# 2  1427218874      USD  1431706954  35000.0  1228074690   1429114954
# 3  1495110632      USD  1500217383   3000.0   330962986   1496329383
# 4  1450121921      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name  \
# 0                            Industrial Bamboo Table
# 1  Custom Pet Portraits on Canvas- "From Pixels t...
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...
# 3             Grandfather Thunder & The Night Horses
# 4  Save Me-A film to hightlight depression (Cance...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                                 slug spotlight  staff_pick  \
# 0                            industrial-bamboo-table     False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...     False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...      True        True
# 3           grandfather-thunder-and-the-night-horses      True       False
# 4                                          save-me-1     False       False
#
#         state state_changed_at   usd_pledged  parent_category  \
# 0      failed       1480966943    240.000000           crafts
# 1      failed       1440417634    247.950175              art
# 2  successful       1431706954  41738.000000             food
# 3  successful       1500217384   3115.000000       publishing
# 4    canceled       1455065666    660.680598     film & video
#
#            category                                        project_url  \
# 0       woodworking  https://www.kickstarter.com/projects/983022919...
# 1          painting  https://www.kickstarter.com/projects/101531536...
# 2       food trucks  https://www.kickstarter.com/projects/372111659...
# 3  children's books  https://www.kickstarter.com/projects/133655246...
# 4    movie theaters  https://www.kickstarter.com/projects/203240363...
#
#                                          rewards_url
# 0  https://www.kickstarter.com/projects/983022919...
# 1  https://www.kickstarter.com/projects/101531536...
# 2  https://www.kickstarter.com/projects/372111659...
# 3  https://www.kickstarter.com/projects/133655246...
# 4  https://www.kickstarter.com/projects/203240363...
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Clean Timestamps

# %%
from datetime import datetime

timestamps = ["created_at", "state_changed_at", "launched_at", "deadline"]
for ts in timestamps:
    month_df[ts + "_clean"] = month_df[ts].apply(datetime.utcfromtimestamp)
month_df.head()
# Out:
#    backers_count                                              blurb country  \
# 0              1  An eco-friendly coffee table that is both func...      US
# 1              3  We take digital uploads and make them handpain...      CA
# 2            243  We are a team of restaurant pros looking to fu...      US
# 3             27  Loosely-based on a Lakota legend, Grandfather ...      US
# 4              3  Save me is a feature film about a depression s...      IE
#
#            created_at currency            deadline     goal          id  \
# 0 2016-09-11 22:05:51      USD 2016-12-05 19:42:23   5000.0  1504859185
# 1 2015-07-10 14:59:32      CAD 2015-08-24 12:00:34   1000.0    49266114
# 2 2015-03-24 17:41:14      USD 2015-05-15 16:22:34  35000.0  1228074690
# 3 2017-05-18 12:30:32      USD 2017-07-16 15:03:03   3000.0   330962986
# 4 2015-12-14 19:38:41      EUR 2016-02-13 01:56:30  15000.0  1657821447
#
#           launched_at                                               name  \
# 0 2016-11-05 18:42:23                            Industrial Bamboo Table
# 1 2015-07-21 12:00:34  Custom Pet Portraits on Canvas- "From Pixels t...
# 2 2015-04-15 16:22:34  The Barmobile: Boston's Mobile Cocktail Cateri...
# 3 2017-06-01 15:03:03             Grandfather Thunder & The Night Horses
# 4 2015-12-15 01:56:30  Save Me-A film to hightlight depression (Cance...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                                 slug spotlight  staff_pick  \
# 0                            industrial-bamboo-table     False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...     False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...      True        True
# 3           grandfather-thunder-and-the-night-horses      True       False
# 4                                          save-me-1     False       False
#
#         state    state_changed_at   usd_pledged  parent_category  \
# 0      failed 2016-12-05 19:42:23    240.000000           crafts
# 1      failed 2015-08-24 12:00:34    247.950175              art
# 2  successful 2015-05-15 16:22:34  41738.000000             food
# 3  successful 2017-07-16 15:03:04   3115.000000       publishing
# 4    canceled 2016-02-10 00:54:26    660.680598     film & video
#
#            category                                        project_url  \
# 0       woodworking  https://www.kickstarter.com/projects/983022919...
# 1          painting  https://www.kickstarter.com/projects/101531536...
# 2       food trucks  https://www.kickstarter.com/projects/372111659...
# 3  children's books  https://www.kickstarter.com/projects/133655246...
# 4    movie theaters  https://www.kickstarter.com/projects/203240363...
#
#                                          rewards_url
# 0  https://www.kickstarter.com/projects/983022919...
# 1  https://www.kickstarter.com/projects/101531536...
# 2  https://www.kickstarter.com/projects/372111659...
# 3  https://www.kickstarter.com/projects/133655246...
# 4  https://www.kickstarter.com/projects/203240363...
#
# [5 rows x 21 columns]

# %%
month_df["project_duration"] = month_df["deadline"] - month_df["created_at"]
month_df["time_til_state_changed"] = (month_df["state_changed_at"] -
                                      month_df["created_at"])
month_df.head()
# Out:
#    backers_count                                              blurb country  \
# 0              1  An eco-friendly coffee table that is both func...      US
# 1              3  We take digital uploads and make them handpain...      CA
# 2            243  We are a team of restaurant pros looking to fu...      US
# 3             27  Loosely-based on a Lakota legend, Grandfather ...      US
# 4              3  Save me is a feature film about a depression s...      IE
#
#            created_at currency            deadline     goal          id  \
# 0 2016-09-11 22:05:51      USD 2016-12-05 19:42:23   5000.0  1504859185
# 1 2015-07-10 14:59:32      CAD 2015-08-24 12:00:34   1000.0    49266114
# 2 2015-03-24 17:41:14      USD 2015-05-15 16:22:34  35000.0  1228074690
# 3 2017-05-18 12:30:32      USD 2017-07-16 15:03:03   3000.0   330962986
# 4 2015-12-14 19:38:41      EUR 2016-02-13 01:56:30  15000.0  1657821447
#
#           launched_at                                               name  \
# 0 2016-11-05 18:42:23                            Industrial Bamboo Table
# 1 2015-07-21 12:00:34  Custom Pet Portraits on Canvas- "From Pixels t...
# 2 2015-04-15 16:22:34  The Barmobile: Boston's Mobile Cocktail Cateri...
# 3 2017-06-01 15:03:03             Grandfather Thunder & The Night Horses
# 4 2015-12-15 01:56:30  Save Me-A film to hightlight depression (Cance...
#
#            ...            staff_pick       state    state_changed_at  \
# 0          ...                 False      failed 2016-12-05 19:42:23
# 1          ...                 False      failed 2015-08-24 12:00:34
# 2          ...                  True  successful 2015-05-15 16:22:34
# 3          ...                 False  successful 2017-07-16 15:03:04
# 4          ...                 False    canceled 2016-02-10 00:54:26
#
#     usd_pledged parent_category          category  \
# 0    240.000000          crafts       woodworking
# 1    247.950175             art          painting
# 2  41738.000000            food       food trucks
# 3   3115.000000      publishing  children's books
# 4    660.680598    film & video    movie theaters
#
#                                          project_url  \
# 0  https://www.kickstarter.com/projects/983022919...
# 1  https://www.kickstarter.com/projects/101531536...
# 2  https://www.kickstarter.com/projects/372111659...
# 3  https://www.kickstarter.com/projects/133655246...
# 4  https://www.kickstarter.com/projects/203240363...
#
#                                          rewards_url project_duration  \
# 0  https://www.kickstarter.com/projects/983022919... 84 days 21:36:32
# 1  https://www.kickstarter.com/projects/101531536... 44 days 21:01:02
# 2  https://www.kickstarter.com/projects/372111659... 51 days 22:41:20
# 3  https://www.kickstarter.com/projects/133655246... 59 days 02:32:31
# 4  https://www.kickstarter.com/projects/203240363... 60 days 06:17:49
#
#   time_til_state_changed
# 0       84 days 21:36:32
# 1       44 days 21:01:02
# 2       51 days 22:41:20
# 3       59 days 02:32:32
# 4       57 days 05:15:45
#
# [5 rows x 23 columns]

# %%
month_df.to_csv(data_dir + "processed/" + "201901.csv")

# %% [markdown]
# ## Process every month from Jan 2016 to Feb 2019

# %%
def collect_month_df(date):
    month_df = pd.DataFrame()
    folder_name = "Kickstarter_" + date + "/"

    for ks in dir_contents:
        baby_df = (pd.read_csv(data_dir +
                               folder_name +
                               ks)[["backers_count", "blurb", "category", "country", "created_at",
                                    "currency", "deadline", "goal", "id", "launched_at", "name",
                                    "pledged", "slug", "spotlight", "staff_pick", "state",
                                    "state_changed_at", "urls", "usd_pledged"]])
        month_df = pd.concat([month_df, baby_df], ignore_index=True)

    return month_df

# %%
def clean_json(month_df, json_cols = ["category", "urls"]):
    for col in json_cols:
        print(col)
        month_df[col] = month_df[col].fillna('')
        month_df[col] = month_df[col].apply(ast.literal_eval)
    
    category_exp = json_normalize(month_df["category"])
    category_tups = category_exp.slug.str.split("/").apply(pd.Series)
    category_tups.columns = ["parent_category", "category"]
    month_df = month_df.drop("category", axis=1)
    month_df = pd.concat([month_df, category_tups], axis=1)

    urls_exp = json_normalize(month_df["urls"])
    urls_exp = urls_exp[["web.project", "web.rewards"]]
    urls_exp.columns = ["project_url", "rewards_url"]
    month_df = month_df.drop("urls", axis=1)
    month_df = pd.concat([month_df, urls_exp], axis=1)
    
    return month_df

# %%
from datetime import datetime

def clean_timestamps(month_df,
                     time_cols = ["created_at", "state_changed_at",
                                  "launched_at", "deadline"]):
    for ts in time_cols:
        month_df[ts + "_clean"] = month_df[ts].apply(datetime.utcfromtimestamp)
    month_df["project_duration"] = (month_df["deadline"] -
                                    month_df["created_at"])
    month_df["time_til_state_changed"] = (month_df["state_changed_at"] -
                                          month_df["created_at"])
    return month_df

# %%
def create_df_for_month(month):
    month_df = collect_month_df(month)
    month_df = clean_json(month_df)
    month_df = clean_timestamps(month_df)
    return month_df

# %%
month_long = "2019-01-17"
month_abbv = "201901"

ks = create_df_for_month(month_long)
print(ks.shape)
ks.to_csv(data_dir + "processed/" + month_abbv + ".csv")
# Out:
# category
# urls
# (207848, 27)
