# %% [markdown]
# # The Success of Kickstarters

# %% [markdown]
# ### *Question:* What predicts the success of Kickstarter projects?

# %% [markdown]
# ### Cleaning & Exploring

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.max_columns = 30

data_dir = "/Users/Kellie/Documents/data301/proj/datasets/final/"

month_df = pd.read_csv(data_dir + "ks201901.csv").set_index("id")
month_df.head()
# Out:
#             backers_count                                              blurb  \
# id
# 1504859185              1  An eco-friendly coffee table that is both func...
# 49266114                3  We take digital uploads and make them handpain...
# 1228074690            243  We are a team of restaurant pros looking to fu...
# 330962986              27  Loosely-based on a Lakota legend, Grandfather ...
# 1657821447              3  Save me is a feature film about a depression s...
#
#            country  created_at currency    deadline     goal  launched_at  \
# id
# 1504859185      US  1473631551      USD  1480966943   5000.0   1478371343
# 49266114        CA  1436540372      CAD  1440417634   1000.0   1437480034
# 1228074690      US  1427218874      USD  1431706954  35000.0   1429114954
# 330962986       US  1495110632      USD  1500217383   3000.0   1496329383
# 1657821447      IE  1450121921      EUR  1455328590  15000.0   1450144590
#
#                                                          name  pledged  \
# id
# 1504859185                            Industrial Bamboo Table    240.0
# 49266114    Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 1228074690  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
# 330962986              Grandfather Thunder & The Night Horses   3115.0
# 1657821447  Save Me-A film to hightlight depression (Cance...    601.0
#
#                                                          slug  spotlight  \
# id
# 1504859185                            industrial-bamboo-table      False
# 49266114    custom-pet-portraits-on-canvas-from-pixels-to-...      False
# 1228074690  the-barmobile-bostons-mobile-cocktail-catering...       True
# 330962986            grandfather-thunder-and-the-night-horses       True
# 1657821447                                          save-me-1      False
#
#             staff_pick       state  state_changed_at  \
# id
# 1504859185       False      failed        1480966943
# 49266114         False      failed        1440417634
# 1228074690        True  successful        1431706954
# 330962986        False  successful        1500217384
# 1657821447       False    canceled        1455065666
#
#                                                          urls   usd_pledged  \
# id
# 1504859185  {"web":{"project":"https://www.kickstarter.com...    240.000000
# 49266114    {"web":{"project":"https://www.kickstarter.com...    247.950175
# 1228074690  {"web":{"project":"https://www.kickstarter.com...  41738.000000
# 330962986   {"web":{"project":"https://www.kickstarter.com...   3115.000000
# 1657821447  {"web":{"project":"https://www.kickstarter.com...    660.680598
#
#            parent_category          category     created_at_clean  \
# id
# 1504859185          crafts       woodworking  2016-09-11 22:05:51
# 49266114               art          painting  2015-07-10 14:59:32
# 1228074690            food       food trucks  2015-03-24 17:41:14
# 330962986       publishing  children's books  2017-05-18 12:30:32
# 1657821447    film & video    movie theaters  2015-12-14 19:38:41
#
#            state_changed_at_clean    launched_at_clean       deadline_clean  \
# id
# 1504859185    2016-12-05 19:42:23  2016-11-05 18:42:23  2016-12-05 19:42:23
# 49266114      2015-08-24 12:00:34  2015-07-21 12:00:34  2015-08-24 12:00:34
# 1228074690    2015-05-15 16:22:34  2015-04-15 16:22:34  2015-05-15 16:22:34
# 330962986     2017-07-16 15:03:04  2017-06-01 15:03:03  2017-07-16 15:03:03
# 1657821447    2016-02-10 00:54:26  2015-12-15 01:56:30  2016-02-13 01:56:30
#
#                       project_duration      time_til_state_changed  avg_pledge
# id
#            avg_pledge201901 backers_count201902 staff_pick201902 state201902  \
# id
# 1951787043        49.211627                  76            False  successful
# 1145162484         0.931424                   1            False      failed
# 835262605         15.578947                  24            False      failed
# 1600105046        20.788807                  61            False  successful
# 1371675865        29.905911                  54            False  successful
#
#            state_changed_at201902  state_changed_at_clean201902  \
# id
# 1951787043             1548981018           2019-02-01 00:30:18
# 1145162484             1549897115           2019-02-11 14:58:35
# 835262605              1549575215           2019-02-07 21:33:35
# 1600105046             1549134658           2019-02-02 19:10:58
# 1371675865             1548171022           2019-01-22 15:30:22
#
#             project_duration201902  time_til_state_changed201902  \
# id
# 1951787043                 4546873                       4546874
# 1145162484                 5230342                       5230344
# 835262605                  3717800                       3717800
# 1600105046                 6008582                       6008583
# 1371675865                 1729336                       1729336
#
#            usd_pledged201902  avg_pledge201902
# id
# 1951787043       3719.416000         48.939684
# 1145162484          0.931424          0.931424
# 835262605         406.000000         16.916667
# 1600105046       1310.141920         21.477736
# 1371675865       1837.943188         34.035985
#
# [5 rows x 35 columns]

# %%
state_colors = month_df.state.map({
    "successful": "g",
    "failed": "r",
    "canceled": "r",
    "live": "y",
    "suspended": "r"
})

f, ax = plt.subplots(1,2,figsize=(18,10))
raw_ax = ax[0]

raw_ax.set_title("backers_count vs. usd_pledged")
raw_ax.scatter(x=month_df.backers_count, y=month_df.usd_pledged,
               c=state_colors, alpha=0.5)

scaled_ax = ax[1]
scaled_ax.set_xlim(left=0, right=10000)
scaled_ax.set_ylim(bottom=0, top=1000000)

scaled_ax.set_title("[SCALED] backers_count vs. usd_pledged")
scaled_ax.scatter(x=month_df.backers_count, y=month_df.usd_pledged,
                  c=state_colors, alpha=0.5)

# %%
f, ax = plt.subplots(1,2,figsize=(18,10))

raw_ax = ax[0]
raw_ax.set_title("backers_count vs. avg_pledge")
raw_ax.scatter(x=month_df.backers_count, y=month_df.avg_pledge,
               c=state_colors, alpha=0.5)

scaled_ax = ax[1]
scaled_ax.set_xlim(left=0, right=10000)
scaled_ax.set_ylim(bottom=0, top=2500)
scaled_ax.set_title("[SCALED] backers_count vs. avg_pledge")
scaled_ax.scatter(x=month_df.backers_count, y=month_df.avg_pledge,
                  c=state_colors, alpha=0.5)

# %%
jan_colors = merged.state201901.map({
    "successful": "g",
    "failed": "r",
    "canceled": "r",
    "live": "y",
    "suspended": "r"
})

feb_colors = merged.state201902.map({
    "successful": "g",
    "failed": "r",
    "canceled": "r",
    "live": "y",
    "suspended": "r"
})

f, ax = plt.subplots(1,2,figsize=(18,10))

jan_ax = ax[0]
jan_ax.set_title("JAN: backers_count vs. avg_pledge")
jan_ax.scatter(x=merged.backers_count201901,
               y=merged.avg_pledge201901,
               c=jan_colors, alpha=0.5)

feb_ax = ax[1]
feb_ax.set_title("FEB: backers_count vs. avg_pledge")
feb_ax.scatter(x=merged.backers_count201902,
               y=merged.avg_pledge201902,
               c=feb_colors, alpha=0.5)

# %% [markdown]
# ## Machine Learning

# %%
from IPython.display import Image

Image("images/best_acc.png")

# %%
Image("images/ks.png")

# %%
Image("images/accuracies.png")

# %%
Image("images/both.png")

# %% [markdown]
# ## Predictions on February's Live Projects

# %%
Image("images/feb_pred.png")
