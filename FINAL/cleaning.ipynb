# %% [markdown]
# # Data Collection and Cleaning

# %% [markdown]
# According to Kickstarter's website, they are a service that "helps artists, musicians, filmmakers, designers, and other creators find the resources and support they need to make their ideas a reality". In other words, they're a crowdfunding platform. Today we examine how to predict whether a Kickstarter will meet its fundraising goals successfully or fail.

# %%
import pandas as pd
import numpy as np
import os
import ast
from datetime import datetime
from random import randint
from pandas.io.json import json_normalize

pd.options.display.max_rows = 10

dir_main = "/Users/Kellie/Documents/data301/proj/"
data_dir = dir_main + "datasets/"

cols = ["backers_count", "blurb", "category", "country", "created_at", "currency",
        "deadline", "goal", "id", "launched_at", "name", "pledged", "slug", "spotlight",
        "staff_pick", "state", "state_changed_at", "urls", "usd_pledged"]

# %% [markdown]
# Kickstarter has privatized its API, so we downloaded our data from [Web Robots](https://webrobots.io/kickstarter-datasets/), a web-scraping service. There are numerous files per month (with the same headers), so we need to begin by collecting those into a single `DataFrame`.

# %%
date = "2019-01-17"
folder_name = "Kickstarter_" + date + "/"

files_for_month = os.listdir(data_dir + folder_name)
files_for_month[:3]
# Out:
# ['Kickstarter040.csv', 'Kickstarter054.csv', 'Kickstarter041.csv']

# %%
month_df = pd.DataFrame()

for ks in files_for_month:
    path = data_dir + folder_name + ks
    baby_df = (pd.read_csv(path)[cols])
    month_df = pd.concat([month_df, baby_df], ignore_index=True)

month_df.head()
# Out:
#    backers_count                                              blurb  \
# 0              1  An eco-friendly coffee table that is both func...
# 1              3  We take digital uploads and make them handpain...
# 2            243  We are a team of restaurant pros looking to fu...
# 3             27  Loosely-based on a Lakota legend, Grandfather ...
# 4              3  Save me is a feature film about a depression s...
#
#                                             category country  created_at  \
# 0  {"id":356,"name":"Woodworking","slug":"crafts/...      US  1473631551
# 1  {"id":23,"name":"Painting","slug":"art/paintin...      CA  1436540372
# 2  {"id":311,"name":"Food Trucks","slug":"food/fo...      US  1427218874
# 3  {"id":46,"name":"Children's Books","slug":"pub...      US  1495110632
# 4  {"id":298,"name":"Movie Theaters","slug":"film...      IE  1450121921
#
#   currency    deadline     goal          id  launched_at  \
# 0      USD  1480966943   5000.0  1504859185   1478371343
# 1      CAD  1440417634   1000.0    49266114   1437480034
# 2      USD  1431706954  35000.0  1228074690   1429114954
# 3      USD  1500217383   3000.0   330962986   1496329383
# 4      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name  pledged  \
# 0                            Industrial Bamboo Table    240.0
# 1  Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
# 3             Grandfather Thunder & The Night Horses   3115.0
# 4  Save Me-A film to hightlight depression (Cance...    601.0
#
#                                                 slug  spotlight  staff_pick  \
# 0                            industrial-bamboo-table      False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...      False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...       True        True
# 3           grandfather-thunder-and-the-night-horses       True       False
# 4                                          save-me-1      False       False
#
#         state  state_changed_at  \
# 0      failed        1480966943
# 1      failed        1440417634
# 2  successful        1431706954
# 3  successful        1500217384
# 4    canceled        1455065666
#
#                                                 urls   usd_pledged
# 0  {"web":{"project":"https://www.kickstarter.com...    240.000000
# 1  {"web":{"project":"https://www.kickstarter.com...    247.950175
# 2  {"web":{"project":"https://www.kickstarter.com...  41738.000000
# 3  {"web":{"project":"https://www.kickstarter.com...   3115.000000
# 4  {"web":{"project":"https://www.kickstarter.com...    660.680598

# %% [markdown]
# According to the Web Robots website, their scraper crawls through the Kickstarter website by exploring categories and subcategories. As a result, some projects are scraped twice. We need to find and remove the duplicates.

# %%
print("original shape:", month_df.shape)
month_df.drop_duplicates(subset=["id"], inplace=True)
month_df.reset_index(inplace=True)
month_df = month_df.drop(["index"], axis=1)
print("shape after dropping duplicates:", month_df.shape)
month_df.head()
# Out:
# original shape: (207848, 19)
# shape after dropping duplicates: (180934, 19)
#    backers_count                                              blurb  \
# 0              1  An eco-friendly coffee table that is both func...
# 1              3  We take digital uploads and make them handpain...
# 2            243  We are a team of restaurant pros looking to fu...
# 3             27  Loosely-based on a Lakota legend, Grandfather ...
# 4              3  Save me is a feature film about a depression s...
#
#                                             category country  created_at  \
# 0  {"id":356,"name":"Woodworking","slug":"crafts/...      US  1473631551
# 1  {"id":23,"name":"Painting","slug":"art/paintin...      CA  1436540372
# 2  {"id":311,"name":"Food Trucks","slug":"food/fo...      US  1427218874
# 3  {"id":46,"name":"Children's Books","slug":"pub...      US  1495110632
# 4  {"id":298,"name":"Movie Theaters","slug":"film...      IE  1450121921
#
#   currency    deadline     goal          id  launched_at  \
# 0      USD  1480966943   5000.0  1504859185   1478371343
# 1      CAD  1440417634   1000.0    49266114   1437480034
# 2      USD  1431706954  35000.0  1228074690   1429114954
# 3      USD  1500217383   3000.0   330962986   1496329383
# 4      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name  pledged  \
# 0                            Industrial Bamboo Table    240.0
# 1  Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
# 3             Grandfather Thunder & The Night Horses   3115.0
# 4  Save Me-A film to hightlight depression (Cance...    601.0
#
#                                                 slug  spotlight  staff_pick  \
# 0                            industrial-bamboo-table      False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...      False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...       True        True
# 3           grandfather-thunder-and-the-night-horses       True       False
# 4                                          save-me-1      False       False
#
#         state  state_changed_at  \
# 0      failed        1480966943
# 1      failed        1440417634
# 2  successful        1431706954
# 3  successful        1500217384
# 4    canceled        1455065666
#
#                                                 urls   usd_pledged
# 0  {"web":{"project":"https://www.kickstarter.com...    240.000000
# 1  {"web":{"project":"https://www.kickstarter.com...    247.950175
# 2  {"web":{"project":"https://www.kickstarter.com...  41738.000000
# 3  {"web":{"project":"https://www.kickstarter.com...   3115.000000
# 4  {"web":{"project":"https://www.kickstarter.com...    660.680598

# %% [markdown]
# ## Clean JSON
# Next, we need to clean up the JSON so we can expand it with `json_normalize`.
#
# _Note:_ We tried to clean numerous JSON fields, but encountered many problems with how to extract the dictionary from the string. For some fields `ast.literal_eval` worked, other fields threw errors under technique but worked with `json.loads`. Because we could not get reliable output from many variables, we removed them from our focus. `urls` was included earlier this week, but somewhere along the way a cosmic flare struck Jupyter and our code to parse the urls stopped working. We have kept that variable in our `DataFrame`, though, as a technique to view the Kickstarter webpages of the project under study.

# %%
json_cols = ["category"]

for col in json_cols:
    month_df[col] = month_df[col].fillna('')
    month_df[col] = month_df[col].apply(ast.literal_eval)
    print(col)
    
month_df.head()
# Out:
# category
#    backers_count                                              blurb  \
# 0              1  An eco-friendly coffee table that is both func...
# 1              3  We take digital uploads and make them handpain...
# 2            243  We are a team of restaurant pros looking to fu...
# 3             27  Loosely-based on a Lakota legend, Grandfather ...
# 4              3  Save me is a feature film about a depression s...
#
#                                             category country  created_at  \
# 0  {'id': 356, 'name': 'Woodworking', 'slug': 'cr...      US  1473631551
# 1  {'id': 23, 'name': 'Painting', 'slug': 'art/pa...      CA  1436540372
# 2  {'id': 311, 'name': 'Food Trucks', 'slug': 'fo...      US  1427218874
# 3  {'id': 46, 'name': 'Children's Books', 'slug':...      US  1495110632
# 4  {'id': 298, 'name': 'Movie Theaters', 'slug': ...      IE  1450121921
#
#   currency    deadline     goal          id  launched_at  \
# 0      USD  1480966943   5000.0  1504859185   1478371343
# 1      CAD  1440417634   1000.0    49266114   1437480034
# 2      USD  1431706954  35000.0  1228074690   1429114954
# 3      USD  1500217383   3000.0   330962986   1496329383
# 4      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name  pledged  \
# 0                            Industrial Bamboo Table    240.0
# 1  Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
# 3             Grandfather Thunder & The Night Horses   3115.0
# 4  Save Me-A film to hightlight depression (Cance...    601.0
#
#                                                 slug  spotlight  staff_pick  \
# 0                            industrial-bamboo-table      False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...      False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...       True        True
# 3           grandfather-thunder-and-the-night-horses       True       False
# 4                                          save-me-1      False       False
#
#         state  state_changed_at  \
# 0      failed        1480966943
# 1      failed        1440417634
# 2  successful        1431706954
# 3  successful        1500217384
# 4    canceled        1455065666
#
#                                                 urls   usd_pledged
# 0  {"web":{"project":"https://www.kickstarter.com...    240.000000
# 1  {"web":{"project":"https://www.kickstarter.com...    247.950175
# 2  {"web":{"project":"https://www.kickstarter.com...  41738.000000
# 3  {"web":{"project":"https://www.kickstarter.com...   3115.000000
# 4  {"web":{"project":"https://www.kickstarter.com...    660.680598

# %%
category_exp = json_normalize(month_df["category"])
month_df = month_df.drop("category", axis=1)
category_tups = category_exp.slug.str.split("/").apply(pd.Series)
category_tups.columns = ["parent_category", "category"]
month_df = pd.concat([month_df, category_tups], axis=1)
month_df.head()
# Out:
#    backers_count                                              blurb country  \
# 0              1  An eco-friendly coffee table that is both func...      US
# 1              3  We take digital uploads and make them handpain...      CA
# 2            243  We are a team of restaurant pros looking to fu...      US
# 3             27  Loosely-based on a Lakota legend, Grandfather ...      US
# 4              3  Save me is a feature film about a depression s...      IE
#
#    created_at currency    deadline     goal          id  launched_at  \
# 0  1473631551      USD  1480966943   5000.0  1504859185   1478371343
# 1  1436540372      CAD  1440417634   1000.0    49266114   1437480034
# 2  1427218874      USD  1431706954  35000.0  1228074690   1429114954
# 3  1495110632      USD  1500217383   3000.0   330962986   1496329383
# 4  1450121921      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name  pledged  \
# 0                            Industrial Bamboo Table    240.0
# 1  Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
# 3             Grandfather Thunder & The Night Horses   3115.0
# 4  Save Me-A film to hightlight depression (Cance...    601.0
#
#                                                 slug  spotlight  staff_pick  \
# 0                            industrial-bamboo-table      False       False
# 1  custom-pet-portraits-on-canvas-from-pixels-to-...      False       False
# 2  the-barmobile-bostons-mobile-cocktail-catering...       True        True
# 3           grandfather-thunder-and-the-night-horses       True       False
# 4                                          save-me-1      False       False
#
#         state  state_changed_at  \
# 0      failed        1480966943
# 1      failed        1440417634
# 2  successful        1431706954
# 3  successful        1500217384
# 4    canceled        1455065666
#
#                                                 urls   usd_pledged  \
# 0  {"web":{"project":"https://www.kickstarter.com...    240.000000
# 1  {"web":{"project":"https://www.kickstarter.com...    247.950175
# 2  {"web":{"project":"https://www.kickstarter.com...  41738.000000
# 3  {"web":{"project":"https://www.kickstarter.com...   3115.000000
# 4  {"web":{"project":"https://www.kickstarter.com...    660.680598
#
#   parent_category          category
# 0          crafts       woodworking
# 1             art          painting
# 2            food       food trucks
# 3      publishing  children's books
# 4    film & video    movie theaters

# %% [markdown]
# ## Clean Timestamps
#
# Convert Unix time into a human-readable format.

# %%
timestamps = ["created_at", "state_changed_at", "launched_at", "deadline"]
for ts in timestamps:
    month_df[ts] = month_df[ts].fillna("")
    month_df[ts + "_clean"] = month_df[ts].apply(datetime.utcfromtimestamp)
month_df.head()
# Out:
#    backers_count                                              blurb country  \
# 0              1  An eco-friendly coffee table that is both func...      US
# 1              3  We take digital uploads and make them handpain...      CA
# 2            243  We are a team of restaurant pros looking to fu...      US
# 3             27  Loosely-based on a Lakota legend, Grandfather ...      US
# 4              3  Save me is a feature film about a depression s...      IE
#
#    created_at currency    deadline     goal          id  launched_at  \
# 0  1473631551      USD  1480966943   5000.0  1504859185   1478371343
# 1  1436540372      CAD  1440417634   1000.0    49266114   1437480034
# 2  1427218874      USD  1431706954  35000.0  1228074690   1429114954
# 3  1495110632      USD  1500217383   3000.0   330962986   1496329383
# 4  1450121921      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name         ...          \
# 0                            Industrial Bamboo Table         ...
# 1  Custom Pet Portraits on Canvas- "From Pixels t...         ...
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...         ...
# 3             Grandfather Thunder & The Night Horses         ...
# 4  Save Me-A film to hightlight depression (Cance...         ...
#
#         state state_changed_at  \
# 0      failed       1480966943
# 1      failed       1440417634
# 2  successful       1431706954
# 3  successful       1500217384
# 4    canceled       1455065666
#
#                                                 urls   usd_pledged  \
# 0  {"web":{"project":"https://www.kickstarter.com...    240.000000
# 1  {"web":{"project":"https://www.kickstarter.com...    247.950175
# 2  {"web":{"project":"https://www.kickstarter.com...  41738.000000
# 3  {"web":{"project":"https://www.kickstarter.com...   3115.000000
# 4  {"web":{"project":"https://www.kickstarter.com...    660.680598
#
#   parent_category          category    created_at_clean  \
# 0          crafts       woodworking 2016-09-11 22:05:51
# 1             art          painting 2015-07-10 14:59:32
# 2            food       food trucks 2015-03-24 17:41:14
# 3      publishing  children's books 2017-05-18 12:30:32
# 4    film & video    movie theaters 2015-12-14 19:38:41
#
#    state_changed_at_clean   launched_at_clean      deadline_clean
# 0     2016-12-05 19:42:23 2016-11-05 18:42:23 2016-12-05 19:42:23
# 1     2015-08-24 12:00:34 2015-07-21 12:00:34 2015-08-24 12:00:34
# 2     2015-05-15 16:22:34 2015-04-15 16:22:34 2015-05-15 16:22:34
# 3     2017-07-16 15:03:04 2017-06-01 15:03:03 2017-07-16 15:03:03
# 4     2016-02-10 00:54:26 2015-12-15 01:56:30 2016-02-13 01:56:30
#
# [5 rows x 24 columns]

# %%
month_df["project_duration"] = (month_df["deadline_clean"] -
                                month_df["created_at_clean"])
month_df["time_til_state_changed"] = (month_df["state_changed_at_clean"] -
                                      month_df["created_at_clean"])
month_df.head()
# Out:
#    backers_count                                              blurb country  \
# 0              1  An eco-friendly coffee table that is both func...      US
# 1              3  We take digital uploads and make them handpain...      CA
# 2            243  We are a team of restaurant pros looking to fu...      US
# 3             27  Loosely-based on a Lakota legend, Grandfather ...      US
# 4              3  Save me is a feature film about a depression s...      IE
#
#    created_at currency    deadline     goal          id  launched_at  \
# 0  1473631551      USD  1480966943   5000.0  1504859185   1478371343
# 1  1436540372      CAD  1440417634   1000.0    49266114   1437480034
# 2  1427218874      USD  1431706954  35000.0  1228074690   1429114954
# 3  1495110632      USD  1500217383   3000.0   330962986   1496329383
# 4  1450121921      EUR  1455328590  15000.0  1657821447   1450144590
#
#                                                 name          ...            \
# 0                            Industrial Bamboo Table          ...
# 1  Custom Pet Portraits on Canvas- "From Pixels t...          ...
# 2  The Barmobile: Boston's Mobile Cocktail Cateri...          ...
# 3             Grandfather Thunder & The Night Horses          ...
# 4  Save Me-A film to hightlight depression (Cance...          ...
#
#                                                 urls   usd_pledged  \
# 0  {"web":{"project":"https://www.kickstarter.com...    240.000000
# 1  {"web":{"project":"https://www.kickstarter.com...    247.950175
# 2  {"web":{"project":"https://www.kickstarter.com...  41738.000000
# 3  {"web":{"project":"https://www.kickstarter.com...   3115.000000
# 4  {"web":{"project":"https://www.kickstarter.com...    660.680598
#
#    parent_category          category    created_at_clean  \
# 0           crafts       woodworking 2016-09-11 22:05:51
# 1              art          painting 2015-07-10 14:59:32
# 2             food       food trucks 2015-03-24 17:41:14
# 3       publishing  children's books 2017-05-18 12:30:32
# 4     film & video    movie theaters 2015-12-14 19:38:41
#
#    state_changed_at_clean   launched_at_clean      deadline_clean  \
# 0     2016-12-05 19:42:23 2016-11-05 18:42:23 2016-12-05 19:42:23
# 1     2015-08-24 12:00:34 2015-07-21 12:00:34 2015-08-24 12:00:34
# 2     2015-05-15 16:22:34 2015-04-15 16:22:34 2015-05-15 16:22:34
# 3     2017-07-16 15:03:04 2017-06-01 15:03:03 2017-07-16 15:03:03
# 4     2016-02-10 00:54:26 2015-12-15 01:56:30 2016-02-13 01:56:30
#
#   project_duration time_til_state_changed
# 0 84 days 21:36:32       84 days 21:36:32
# 1 44 days 21:01:02       44 days 21:01:02
# 2 51 days 22:41:20       51 days 22:41:20
# 3 59 days 02:32:31       59 days 02:32:32
# 4 60 days 06:17:49       57 days 05:15:45
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Export
# This `DataFrame` is the final clean form.

# %%
month_df = month_df.set_index("id")
month_df.head()
# Out:
#             backers_count                                              blurb  \
# id
# 1504859185              1  An eco-friendly coffee table that is both func...
# 49266114                3  We take digital uploads and make them handpain...
# 1228074690            243  We are a team of restaurant pros looking to fu...
# 330962986              27  Loosely-based on a Lakota legend, Grandfather ...
# 1657821447              3  Save me is a feature film about a depression s...
#
#            country  created_at currency    deadline     goal  launched_at  \
# id
# 1504859185      US  1473631551      USD  1480966943   5000.0   1478371343
# 49266114        CA  1436540372      CAD  1440417634   1000.0   1437480034
# 1228074690      US  1427218874      USD  1431706954  35000.0   1429114954
# 330962986       US  1495110632      USD  1500217383   3000.0   1496329383
# 1657821447      IE  1450121921      EUR  1455328590  15000.0   1450144590
#
#                                                          name  pledged  \
# id
# 1504859185                            Industrial Bamboo Table    240.0
# 49266114    Custom Pet Portraits on Canvas- "From Pixels t...    322.0
# 1228074690  The Barmobile: Boston's Mobile Cocktail Cateri...  41738.0
# 330962986              Grandfather Thunder & The Night Horses   3115.0
# 1657821447  Save Me-A film to hightlight depression (Cance...    601.0
#
#                     ...            \
# id                  ...
# 1504859185          ...
# 49266114            ...
# 1228074690          ...
# 330962986           ...
# 1657821447          ...
#
#                                                          urls   usd_pledged  \
# id
# 1504859185  {"web":{"project":"https://www.kickstarter.com...    240.000000
# 49266114    {"web":{"project":"https://www.kickstarter.com...    247.950175
# 1228074690  {"web":{"project":"https://www.kickstarter.com...  41738.000000
# 330962986   {"web":{"project":"https://www.kickstarter.com...   3115.000000
# 1657821447  {"web":{"project":"https://www.kickstarter.com...    660.680598
#
#             parent_category          category    created_at_clean  \
# id
# 1504859185           crafts       woodworking 2016-09-11 22:05:51
# 49266114                art          painting 2015-07-10 14:59:32
# 1228074690             food       food trucks 2015-03-24 17:41:14
# 330962986        publishing  children's books 2017-05-18 12:30:32
# 1657821447     film & video    movie theaters 2015-12-14 19:38:41
#
#            state_changed_at_clean   launched_at_clean      deadline_clean  \
# id
# 1504859185    2016-12-05 19:42:23 2016-11-05 18:42:23 2016-12-05 19:42:23
# 49266114      2015-08-24 12:00:34 2015-07-21 12:00:34 2015-08-24 12:00:34
# 1228074690    2015-05-15 16:22:34 2015-04-15 16:22:34 2015-05-15 16:22:34
# 330962986     2017-07-16 15:03:04 2017-06-01 15:03:03 2017-07-16 15:03:03
# 1657821447    2016-02-10 00:54:26 2015-12-15 01:56:30 2016-02-13 01:56:30
#
#            project_duration time_til_state_changed
# id
# 1504859185 84 days 21:36:32       84 days 21:36:32
# 49266114   44 days 21:01:02       44 days 21:01:02
# 1228074690 51 days 22:41:20       51 days 22:41:20
# 330962986  59 days 02:32:31       59 days 02:32:32
# 1657821447 60 days 06:17:49       57 days 05:15:45
#
# [5 rows x 25 columns]

# %%
date_short = date.replace("-", "")[:6]
month_df.to_csv(data_dir + "final/ks" + date_short + ".csv")
